# %%
# Run this cell to set up your notebook
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import seaborn as sns
sns.set()
sns.set_context("talk")
import re

from IPython.display import display, Latex, Markdown
# The following should run
# import tweepy

import json
key_file = 'panchamKeys.json'
# Loading your keys from keys.json (which you should have filled
# in in question 1):
with open(key_file) as f:
    keys = json.load(f)
# if you print or view the contents of keys be sure to delete the cell!

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Using cached tweepy-3.5.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.4.3 in /Users/panchamyadav/anaconda3/lib/python3.5/site-packages (from tweepy)
# Collecting requests-oauthlib>=0.4.1 (from tweepy)
#   Using cached requests_oauthlib-0.8.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.7.3 in /Users/panchamyadav/anaconda3/lib/python3.5/site-packages (from tweepy)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/panchamyadav/anaconda3/lib/python3.5/site-packages (from requests>=2.4.3->tweepy)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/panchamyadav/anaconda3/lib/python3.5/site-packages (from requests>=2.4.3->tweepy)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/panchamyadav/anaconda3/lib/python3.5/site-packages (from requests>=2.4.3->tweepy)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/panchamyadav/anaconda3/lib/python3.5/site-packages (from requests>=2.4.3->tweepy)
# Collecting oauthlib>=0.6.2 (from requests-oauthlib>=0.4.1->tweepy)
#   Downloading oauthlib-2.0.6.tar.gz (127kB)
#     100% |████████████████████████████████| 133kB 1.6MB/s ta 0:00:01
# Building wheels for collected packages: oauthlib
#   Running setup.py bdist_wheel for oauthlib ... done
#   Stored in directory: /Users/panchamyadav/Library/Caches/pip/wheels/e5/46/f7/bb2fde81726295a13a71e3c6396d362ab408921c6562d6efc0
# Successfully built oauthlib
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-2.0.6 requests-oauthlib-0.8.0 tweepy-3.5.0

# %%
# The following should run
import tweepy

# %%
auth = tweepy.OAuthHandler(keys["consumer_key"], keys["consumer_secret"])
auth.set_access_token(keys["access_token"], keys["access_token_secret"])
api = tweepy.API(auth)

# Getting as many recent tweets by @BerkeleyData as Twitter will let us have:
example_tweets = list(tweepy.Cursor(api.search, q="climate", lang="en",count=10).items())

ds_tweets_save_path = "twitter_data.txt"

# Saving the tweets to a file as "pickled" objects:
with open(ds_tweets_save_path, "wb") as f:
    import pickle
    pickle.dump(example_tweets, f)

# Re-loading the results:
with open(ds_tweets_save_path, "rb") as f:
    import pickle
    example_tweets = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-56-d04cfa9da08c> in <module>()
#       4
#       5 # Getting as many recent tweets by @BerkeleyData as Twitter will let us have:
# ----> 6 example_tweets = list(tweepy.Cursor(api.search, q="climate", lang="en",count=10).items())
#       7
#       8 ds_tweets_save_path = "twitter_data.txt"
#
# ~/anaconda3/lib/python3.5/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~/anaconda3/lib/python3.5/site-packages/tweepy/cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# ~/anaconda3/lib/python3.5/site-packages/tweepy/cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# ~/anaconda3/lib/python3.5/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# ~/anaconda3/lib/python3.5/site-packages/tweepy/binder.py in execute(self)
#     227                     raise RateLimitError(error_msg, resp)
#     228                 else:
# --> 229                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     230
#     231             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429

# %%
print(example_tweets)
